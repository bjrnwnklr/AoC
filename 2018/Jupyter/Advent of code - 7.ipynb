# %% [markdown]
# # Day 7, part 1
#
# The instructions specify a series of steps and requirements about which steps must be finished before others can begin (your puzzle input). Each step is designated by a single letter. For example, suppose you have the following instructions:
#
# Step C must be finished before step A can begin.
# Step C must be finished before step F can begin.
# Step A must be finished before step B can begin.
# Step A must be finished before step D can begin.
# Step B must be finished before step E can begin.
# Step D must be finished before step E can begin.
# Step F must be finished before step E can begin.
# Visually, these requirements look like this:
#
#
#   -->A--->B--
#  /    \      \
# C      -->D----->E
#  \           /
#   ---->F-----
# Your first goal is to determine the order in which the steps should be completed. If more than one step is ready, choose the step which is first alphabetically. In this example, the steps would be completed as follows:
#
# Only C is available, and so it is done first.
# Next, both A and F are available. A is first alphabetically, so it is done next.
# Then, even though F was available earlier, steps B and D are now also available, and B is the first alphabetically of the three.
# After that, only D and F are available. E is not available because only some of its prerequisites are complete. Therefore, D is completed next.
# F is the only choice, so it is done next.
# Finally, E is completed.
# So, in this example, the correct order is CABDFE.

# %% [markdown]
# Solution uses a priority queue or heap queue, which always delivers the smallest element from the queue when popped.
#
# Correct solution: BGJCNLQUYIFMOEZTADKSPVXRHW

# %%
from collections import defaultdict
from heapq import heappush, heappop
input_list = open(r'D:\Python\Advent\7.1\input.txt', 'r').readlines()

# edge dictionary - stores the edges identified (key is the starting point)
edges = defaultdict(list)
pred = defaultdict(list)

for line in input_list:
    step1, step2 = line[5], line[-13]
    edges[step1].append(step2) 
    pred[step2].append(step1)
    
print('Edges:')
for e in edges:
    edges[e] = sorted(edges[e])
    print(e, edges[e])
    
print('Predecessors:')
for p in pred:
    pred[p] = sorted(pred[p])
    print(p, pred[p])
    
q = []
starters = set(edges.keys()) - set(pred.keys())
for starter in starters:
    heappush(q, starter)
print('Starters:', starters)
    
order = []

while q:
    print('Queue:', q)
    next_item = heappop(q)
    order.append(next_item)
    print('Order:', order)
    for s in edges[next_item]:
        print('Queue in loop:', q)
        print('next item s:', s)
        pred_items = pred[s]
        print('predecessors pred_items:', pred_items)
        if s not in order and all(p in order for p in pred_items):
            heappush(q, s)
            print('pushed %s into %s' % (s, q))
            
print(''.join(order))
# Out:
# Edges:
# B ['E', 'G', 'O', 'Q', 'R', 'W']
# G ['A', 'F', 'J', 'M', 'Q', 'T', 'U', 'Y', 'Z']
# J ['C', 'D', 'F', 'N', 'Z']
# U ['S', 'Z']
# C ['D', 'M', 'R']
# Y ['E', 'I', 'M', 'O']
# Q ['A', 'O', 'V']
# N ['I', 'L', 'R', 'V']
# O ['A', 'E', 'P', 'Z']
# Z ['T', 'V', 'X']
# I ['D', 'F', 'H', 'M', 'S', 'V']
# L ['K', 'S', 'V', 'W']
# F ['D', 'K', 'R', 'T', 'V', 'W']
# T ['A', 'K', 'R', 'S', 'W', 'X']
# A ['D', 'S', 'X']
# K ['P', 'V', 'X']
# S ['H', 'P', 'W', 'X']
# M ['E', 'H', 'P', 'R', 'V', 'X']
# E ['D', 'H', 'P', 'W']
# D ['H', 'P', 'R', 'V']
# P ['R', 'V', 'W', 'X']
# X ['H', 'R', 'W']
# V ['H', 'R', 'W']
# R ['H']
# H ['W']
# Predecessors:
# G ['B']
# J ['G']
# F ['G', 'I', 'J']
# Z ['G', 'J', 'O', 'U']
# M ['C', 'G', 'I', 'Y']
# I ['N', 'Y']
# A ['G', 'O', 'Q', 'T']
# L ['N']
# T ['F', 'G', 'Z']
# H ['D', 'E', 'I', 'M', 'R', 'S', 'V', 'X']
# W ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# X ['A', 'K', 'M', 'P', 'S', 'T', 'Z']
# P ['D', 'E', 'K', 'M', 'O', 'S']
# E ['B', 'M', 'O', 'Y']
# R ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# V ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# K ['F', 'L', 'T']
# S ['A', 'I', 'L', 'T', 'U']
# N ['J']
# Q ['B', 'G']
# Y ['G']
# O ['B', 'Q', 'Y']
# D ['A', 'C', 'E', 'F', 'I', 'J']
# U ['G']
# C ['J']
# Starters: {'B'}
# Queue: ['B']
# Order: ['B']
# Queue in loop: []
# next item s: E
# predecessors pred_items: ['B', 'M', 'O', 'Y']
# Queue in loop: []
# next item s: G
# predecessors pred_items: ['B']
# pushed G into ['G']
# Queue in loop: ['G']
# next item s: O
# predecessors pred_items: ['B', 'Q', 'Y']
# Queue in loop: ['G']
# next item s: Q
# predecessors pred_items: ['B', 'G']
# Queue in loop: ['G']
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# Queue in loop: ['G']
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# Queue: ['G']
# Order: ['B', 'G']
# Queue in loop: []
# next item s: A
# predecessors pred_items: ['G', 'O', 'Q', 'T']
# Queue in loop: []
# next item s: F
# predecessors pred_items: ['G', 'I', 'J']
# Queue in loop: []
# next item s: J
# predecessors pred_items: ['G']
# pushed J into ['J']
# Queue in loop: ['J']
# next item s: M
# predecessors pred_items: ['C', 'G', 'I', 'Y']
# Queue in loop: ['J']
# next item s: Q
# predecessors pred_items: ['B', 'G']
# pushed Q into ['J', 'Q']
# Queue in loop: ['J', 'Q']
# next item s: T
# predecessors pred_items: ['F', 'G', 'Z']
# Queue in loop: ['J', 'Q']
# next item s: U
# predecessors pred_items: ['G']
# pushed U into ['J', 'Q', 'U']
# Queue in loop: ['J', 'Q', 'U']
# next item s: Y
# predecessors pred_items: ['G']
# pushed Y into ['J', 'Q', 'U', 'Y']
# Queue in loop: ['J', 'Q', 'U', 'Y']
# next item s: Z
# predecessors pred_items: ['G', 'J', 'O', 'U']
# Queue: ['J', 'Q', 'U', 'Y']
# Order: ['B', 'G', 'J']
# Queue in loop: ['Q', 'Y', 'U']
# next item s: C
# predecessors pred_items: ['J']
# pushed C into ['C', 'Q', 'U', 'Y']
# Queue in loop: ['C', 'Q', 'U', 'Y']
# next item s: D
# predecessors pred_items: ['A', 'C', 'E', 'F', 'I', 'J']
# Queue in loop: ['C', 'Q', 'U', 'Y']
# next item s: F
# predecessors pred_items: ['G', 'I', 'J']
# Queue in loop: ['C', 'Q', 'U', 'Y']
# next item s: N
# predecessors pred_items: ['J']
# pushed N into ['C', 'N', 'U', 'Y', 'Q']
# Queue in loop: ['C', 'N', 'U', 'Y', 'Q']
# next item s: Z
# predecessors pred_items: ['G', 'J', 'O', 'U']
# Queue: ['C', 'N', 'U', 'Y', 'Q']
# Order: ['B', 'G', 'J', 'C']
# Queue in loop: ['N', 'Q', 'U', 'Y']
# next item s: D
# predecessors pred_items: ['A', 'C', 'E', 'F', 'I', 'J']
# Queue in loop: ['N', 'Q', 'U', 'Y']
# next item s: M
# predecessors pred_items: ['C', 'G', 'I', 'Y']
# Queue in loop: ['N', 'Q', 'U', 'Y']
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# Queue: ['N', 'Q', 'U', 'Y']
# Order: ['B', 'G', 'J', 'C', 'N']
# Queue in loop: ['Q', 'Y', 'U']
# next item s: I
# predecessors pred_items: ['N', 'Y']
# Queue in loop: ['Q', 'Y', 'U']
# next item s: L
# predecessors pred_items: ['N']
# pushed L into ['L', 'Q', 'U', 'Y']
# Queue in loop: ['L', 'Q', 'U', 'Y']
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# Queue in loop: ['L', 'Q', 'U', 'Y']
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# Queue: ['L', 'Q', 'U', 'Y']
# Order: ['B', 'G', 'J', 'C', 'N', 'L']
# Queue in loop: ['Q', 'Y', 'U']
# next item s: K
# predecessors pred_items: ['F', 'L', 'T']
# Queue in loop: ['Q', 'Y', 'U']
# next item s: S
# predecessors pred_items: ['A', 'I', 'L', 'T', 'U']
# Queue in loop: ['Q', 'Y', 'U']
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# Queue in loop: ['Q', 'Y', 'U']
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# Queue: ['Q', 'Y', 'U']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q']
# Queue in loop: ['U', 'Y']
# next item s: A
# predecessors pred_items: ['G', 'O', 'Q', 'T']
# Queue in loop: ['U', 'Y']
# next item s: O
# predecessors pred_items: ['B', 'Q', 'Y']
# Queue in loop: ['U', 'Y']
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# Queue: ['U', 'Y']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U']
# Queue in loop: ['Y']
# next item s: S
# predecessors pred_items: ['A', 'I', 'L', 'T', 'U']
# Queue in loop: ['Y']
# next item s: Z
# predecessors pred_items: ['G', 'J', 'O', 'U']
# Queue: ['Y']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y']
# Queue in loop: []
# next item s: E
# predecessors pred_items: ['B', 'M', 'O', 'Y']
# Queue in loop: []
# next item s: I
# predecessors pred_items: ['N', 'Y']
# pushed I into ['I']
# Queue in loop: ['I']
# next item s: M
# predecessors pred_items: ['C', 'G', 'I', 'Y']
# Queue in loop: ['I']
# next item s: O
# predecessors pred_items: ['B', 'Q', 'Y']
# pushed O into ['I', 'O']
# Queue: ['I', 'O']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I']
# Queue in loop: ['O']
# next item s: D
# predecessors pred_items: ['A', 'C', 'E', 'F', 'I', 'J']
# Queue in loop: ['O']
# next item s: F
# predecessors pred_items: ['G', 'I', 'J']
# pushed F into ['F', 'O']
# Queue in loop: ['F', 'O']
# next item s: H
# predecessors pred_items: ['D', 'E', 'I', 'M', 'R', 'S', 'V', 'X']
# Queue in loop: ['F', 'O']
# next item s: M
# predecessors pred_items: ['C', 'G', 'I', 'Y']
# pushed M into ['F', 'O', 'M']
# Queue in loop: ['F', 'O', 'M']
# next item s: S
# predecessors pred_items: ['A', 'I', 'L', 'T', 'U']
# Queue in loop: ['F', 'O', 'M']
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# Queue: ['F', 'O', 'M']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F']
# Queue in loop: ['M', 'O']
# next item s: D
# predecessors pred_items: ['A', 'C', 'E', 'F', 'I', 'J']
# Queue in loop: ['M', 'O']
# next item s: K
# predecessors pred_items: ['F', 'L', 'T']
# Queue in loop: ['M', 'O']
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# Queue in loop: ['M', 'O']
# next item s: T
# predecessors pred_items: ['F', 'G', 'Z']
# Queue in loop: ['M', 'O']
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# Queue in loop: ['M', 'O']
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# Queue: ['M', 'O']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M']
# Queue in loop: ['O']
# next item s: E
# predecessors pred_items: ['B', 'M', 'O', 'Y']
# Queue in loop: ['O']
# next item s: H
# predecessors pred_items: ['D', 'E', 'I', 'M', 'R', 'S', 'V', 'X']
# Queue in loop: ['O']
# next item s: P
# predecessors pred_items: ['D', 'E', 'K', 'M', 'O', 'S']
# Queue in loop: ['O']
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# Queue in loop: ['O']
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# Queue in loop: ['O']
# next item s: X
# predecessors pred_items: ['A', 'K', 'M', 'P', 'S', 'T', 'Z']
# Queue: ['O']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O']
# Queue in loop: []
# next item s: A
# predecessors pred_items: ['G', 'O', 'Q', 'T']
# Queue in loop: []
# next item s: E
# predecessors pred_items: ['B', 'M', 'O', 'Y']
# pushed E into ['E']
# Queue in loop: ['E']
# next item s: P
# predecessors pred_items: ['D', 'E', 'K', 'M', 'O', 'S']
# Queue in loop: ['E']
# next item s: Z
# predecessors pred_items: ['G', 'J', 'O', 'U']
# pushed Z into ['E', 'Z']
# Queue: ['E', 'Z']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E']
# Queue in loop: ['Z']
# next item s: D
# predecessors pred_items: ['A', 'C', 'E', 'F', 'I', 'J']
# Queue in loop: ['Z']
# next item s: H
# predecessors pred_items: ['D', 'E', 'I', 'M', 'R', 'S', 'V', 'X']
# Queue in loop: ['Z']
# next item s: P
# predecessors pred_items: ['D', 'E', 'K', 'M', 'O', 'S']
# Queue in loop: ['Z']
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# Queue: ['Z']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z']
# Queue in loop: []
# next item s: T
# predecessors pred_items: ['F', 'G', 'Z']
# pushed T into ['T']
# Queue in loop: ['T']
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# Queue in loop: ['T']
# next item s: X
# predecessors pred_items: ['A', 'K', 'M', 'P', 'S', 'T', 'Z']
# Queue: ['T']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T']
# Queue in loop: []
# next item s: A
# predecessors pred_items: ['G', 'O', 'Q', 'T']
# pushed A into ['A']
# Queue in loop: ['A']
# next item s: K
# predecessors pred_items: ['F', 'L', 'T']
# pushed K into ['A', 'K']
# Queue in loop: ['A', 'K']
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# Queue in loop: ['A', 'K']
# next item s: S
# predecessors pred_items: ['A', 'I', 'L', 'T', 'U']
# Queue in loop: ['A', 'K']
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# Queue in loop: ['A', 'K']
# next item s: X
# predecessors pred_items: ['A', 'K', 'M', 'P', 'S', 'T', 'Z']
# Queue: ['A', 'K']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A']
# Queue in loop: ['K']
# next item s: D
# predecessors pred_items: ['A', 'C', 'E', 'F', 'I', 'J']
# pushed D into ['D', 'K']
# Queue in loop: ['D', 'K']
# next item s: S
# predecessors pred_items: ['A', 'I', 'L', 'T', 'U']
# pushed S into ['D', 'K', 'S']
# Queue in loop: ['D', 'K', 'S']
# next item s: X
# predecessors pred_items: ['A', 'K', 'M', 'P', 'S', 'T', 'Z']
# Queue: ['D', 'K', 'S']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A', 'D']
# Queue in loop: ['K', 'S']
# next item s: H
# predecessors pred_items: ['D', 'E', 'I', 'M', 'R', 'S', 'V', 'X']
# Queue in loop: ['K', 'S']
# next item s: P
# predecessors pred_items: ['D', 'E', 'K', 'M', 'O', 'S']
# Queue in loop: ['K', 'S']
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# Queue in loop: ['K', 'S']
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# Queue: ['K', 'S']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A', 'D', 'K']
# Queue in loop: ['S']
# next item s: P
# predecessors pred_items: ['D', 'E', 'K', 'M', 'O', 'S']
# Queue in loop: ['S']
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# Queue in loop: ['S']
# next item s: X
# predecessors pred_items: ['A', 'K', 'M', 'P', 'S', 'T', 'Z']
# Queue: ['S']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A', 'D', 'K', 'S']
# Queue in loop: []
# next item s: H
# predecessors pred_items: ['D', 'E', 'I', 'M', 'R', 'S', 'V', 'X']
# Queue in loop: []
# next item s: P
# predecessors pred_items: ['D', 'E', 'K', 'M', 'O', 'S']
# pushed P into ['P']
# Queue in loop: ['P']
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# Queue in loop: ['P']
# next item s: X
# predecessors pred_items: ['A', 'K', 'M', 'P', 'S', 'T', 'Z']
# Queue: ['P']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A', 'D', 'K', 'S', 'P']
# Queue in loop: []
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# Queue in loop: []
# next item s: V
# predecessors pred_items: ['D', 'F', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'Z']
# pushed V into ['V']
# Queue in loop: ['V']
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# Queue in loop: ['V']
# next item s: X
# predecessors pred_items: ['A', 'K', 'M', 'P', 'S', 'T', 'Z']
# pushed X into ['V', 'X']
# Queue: ['V', 'X']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A', 'D', 'K', 'S', 'P', 'V']
# Queue in loop: ['X']
# next item s: H
# predecessors pred_items: ['D', 'E', 'I', 'M', 'R', 'S', 'V', 'X']
# Queue in loop: ['X']
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# Queue in loop: ['X']
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# Queue: ['X']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A', 'D', 'K', 'S', 'P', 'V', 'X']
# Queue in loop: []
# next item s: H
# predecessors pred_items: ['D', 'E', 'I', 'M', 'R', 'S', 'V', 'X']
# Queue in loop: []
# next item s: R
# predecessors pred_items: ['B', 'C', 'D', 'F', 'M', 'N', 'P', 'T', 'V', 'X']
# pushed R into ['R']
# Queue in loop: ['R']
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# Queue: ['R']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A', 'D', 'K', 'S', 'P', 'V', 'X', 'R']
# Queue in loop: []
# next item s: H
# predecessors pred_items: ['D', 'E', 'I', 'M', 'R', 'S', 'V', 'X']
# pushed H into ['H']
# Queue: ['H']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A', 'D', 'K', 'S', 'P', 'V', 'X', 'R', 'H']
# Queue in loop: []
# next item s: W
# predecessors pred_items: ['B', 'E', 'F', 'H', 'L', 'P', 'S', 'T', 'V', 'X']
# pushed W into ['W']
# Queue: ['W']
# Order: ['B', 'G', 'J', 'C', 'N', 'L', 'Q', 'U', 'Y', 'I', 'F', 'M', 'O', 'E', 'Z', 'T', 'A', 'D', 'K', 'S', 'P', 'V', 'X', 'R', 'H', 'W']
# BGJCNLQUYIFMOEZTADKSPVXRHW

# %% [markdown]
# # part 2
